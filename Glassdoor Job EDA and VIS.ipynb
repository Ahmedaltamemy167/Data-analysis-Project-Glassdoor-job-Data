# %%
import pandas as pd 
import matplotlib.pylab as plt 
import seaborn as sns

# %%
df = pd.read_csv("salary_data_cleaned")
df
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 687         949       Principal, Data Science - Advanced Analytics
# 688         950           Sr Scientist, Immuno-Oncology - Oncology
# 689         951                               Senior Data Engineer
# 690         952  Project Scientist - Auton Lab, Robotics Institute
# 691         955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# ...

# %%
df.age.hist()
# Out:
# <AxesSubplot:>

# %%
df.Rating.hist()
# Out:
# <AxesSubplot:>

# %%
df.desc_len.hist()
# Out:
# <AxesSubplot:>

# %%
df.jop_state.value_counts()[:15].plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x = "python_yn", data = df)
# Out:
# <AxesSubplot:xlabel='python_yn', ylabel='count'>

# %%
sns.countplot(x = "R_yn", data = df)
# Out:
# <AxesSubplot:xlabel='R_yn', ylabel='count'>

# %%
sns.countplot(x = "spark", data = df)
# Out:
# <AxesSubplot:xlabel='spark', ylabel='count'>

# %%
sns.countplot(x = "aws", data = df)
# Out:
# <AxesSubplot:xlabel='aws', ylabel='count'>

# %%
sns.countplot(x = "excel", data = df)
# Out:
# <AxesSubplot:xlabel='excel', ylabel='count'>

# %%
df.corr()
# Out:
#             Unnamed: 0    Rating   Founded  min_salary  max_salary  \
# Unnamed: 0    1.000000 -0.113536 -0.028872   -0.059651   -0.035903
# Rating       -0.113536  1.000000  0.079415    0.050384    0.041627
# Founded      -0.028872  0.079415  1.000000   -0.011258   -0.031780
# min_salary   -0.059651  0.050384 -0.011258    1.000000    0.951258
# max_salary   -0.035903  0.041627 -0.031780    0.951258    1.000000
# avg_salary   -0.059651  0.050384 -0.011258    1.000000    0.951258
# same_state    0.001111  0.031094  0.217089   -0.032329   -0.026804
# age           0.028872 -0.079415 -1.000000    0.011258    0.031780
# python_yn    -0.111236  0.126806  0.128934    0.354162    0.313180
# R_yn         -0.037144 -0.012360  0.020450   -0.040647   -0.039735
# spark        -0.065820  0.157068  0.122316    0.176999    0.172924
# aws           0.034619  0.081184  0.031688    0.172228    0.176681
# excel        -0.025492 -0.044542 -0.049395   -0.070893   -0.062610
# ...

# %%
plt.figure(figsize= (16,8))
sns.heatmap(data =round(df.corr(), 2) ,annot = True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize= (10,6))
sns.set_palette("Set2")
df["Type of ownership"].value_counts()[:5].plot(kind= "pie", autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Type of ownership'>

# %%
plt.figure(figsize= (10,6))
sns.countplot(data = df, x = 'Size')
plt.xticks(rotation = 90)
plt.show()

# %%
df.sample()
# Out:
#      Unnamed: 0                             Job Title  \
# 218         277  Data Scientist (Actuary, FSA or ASA)
#
#                  Salary Estimate  \
# 218  $81K-$133K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 218  At Legal & General America, we aim to make a p...     3.8
#
#                      Company Name       Location   Headquarters  \
# 218  Legal & General America\n3.8  Frederick, MD  Frederick, MD
#
#                       Size  Founded  ...              company_txt jop_state  \
# 218  501 to 1000 employees     1981  ...  Legal & General America        MD
#
#     same_state age python_yn  R_yn  spark  aws excel desc_len
# 218          1  43         1     0      0    0     1     3010
#
# [1 rows x 28 columns]

# %%
sns.set_palette("deep")
sns.countplot(data = df , x = "same_state");

# %%
df.company_txt.value_counts()[:15].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df_cat = df[['Location', 'Headquarters', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue', 'company_txt', 'jop_state','same_state', 'python_yn', 'R_yn',
       'spark', 'aws', 'excel']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    chart = sns.barplot(x=cat_num[cat_num.index[:10]], y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()

# %%
sns.regplot(data = df , y = 'Rating' , x = "min_salary")
# Out:
# <AxesSubplot:xlabel='min_salary', ylabel='Rating'>

# %%
sns.regplot(data = df , y = 'Rating' , x = "max_salary")
# Out:
# <AxesSubplot:xlabel='max_salary', ylabel='Rating'>

# %%
sns.regplot(data = df , y = 'Rating' , x = "avg_salary")
# Out:
# <AxesSubplot:xlabel='avg_salary', ylabel='Rating'>
